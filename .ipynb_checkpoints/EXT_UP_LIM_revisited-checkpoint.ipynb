# %%
import os

import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
from astropy.coordinates import SkyCoord
from astropy.io import fits
from gammapy.irf import load_irf_dict_from_file
from scipy.stats import chi2, poisson
from scipy.optimize import curve_fit

# %%
# TODO: change name if needed
name = "Mrk501"
blazar_coord = SkyCoord.from_name(name)
# TODO: change data_folder if needed
data_folder = "../cta_dc_data/mrk_501/"
data_folder_40deg = data_folder+"40deg/"
data_folder_20deg = data_folder+"20deg/"
irf_file_40deg = "../cta_dc_data/irfs/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits.gz"
irf_file_20deg = "../cta_dc_data/irfs/Prod5-North-20deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits.gz"

# %%
blazar_l = blazar_coord.galactic.l.deg
blazar_b = blazar_coord.galactic.b.deg

hbus_40deg = []
hbus_20deg = []
for filename in os.listdir(data_folder_40deg):
    hbus_40deg.append(fits.open(data_folder_40deg + filename))
for filename in os.listdir(data_folder_20deg):
    hbus_20deg.append(fits.open(data_folder_20deg + filename))
    
irf_40deg = load_irf_dict_from_file(irf_file_40deg)
irf_20deg = load_irf_dict_from_file(irf_file_20deg)
print(f"Pointings 40deg: {len(hbus_40deg)}")
print(f"Pointings 20deg: {len(hbus_20deg)}")
# Out:
# Pointings 40deg: 60
# Pointings 20deg: 66

# %%
e_bins=np.logspace(np.log10(0.05), np.log10(50), 16)
e_mins=e_bins[:-1]
e_maxs=e_bins[1:]
e=np.sqrt(e_mins*e_maxs)
de=e_maxs-e_mins

th2_bins=np.linspace(0,0.16,17)
th2=(th2_bins[1:]+th2_bins[:-1])/2.

# %% [markdown]
# **Data collecting and overview**

# %%
def collect_data(hbus):
    cts_s = np.zeros((len(e), len(th2)))
    cts_b = np.zeros((len(e), len(th2)))
    t_expo = 0

    for hbu in hbus:
        data_raw = hbu["EVENTS"].data
    
        t = data_raw["TIME"]
        t = np.sort(t)
        t_expo += t[-1] - t[0]
    
        coord = SkyCoord(
            ra=data_raw["RA"] * u.deg, dec=data_raw["DEC"] * u.deg, frame="icrs"
        )
    
        pointing_coord = SkyCoord(
            ra=hbu[1].header["RA_PNT"] * u.deg,
            dec=hbu[1].header["DEC_PNT"] * u.deg,
            frame="icrs",
        )
    
        bkg_center = SkyCoord(
            l=2 * pointing_coord.galactic.l - blazar_coord.galactic.l,
            b=2 * pointing_coord.galactic.b - blazar_coord.galactic.b,
            frame="galactic",
        )
        
        seps = coord.separation(blazar_coord).degree
        seps_b = coord.separation(bkg_center).degree
        src_pos_mask = seps < bkg_subtraction_radius
        bkg_pos_mask = seps_b < bkg_subtraction_radius
    
        energ = data_raw["ENERGY"]
    
        for i, (energ_min, energ_max) in enumerate(zip(e_mins, e_maxs)):
            m_s = (energ>energ_min) & (energ<energ_max) & src_pos_mask
            m_b = (energ>energ_min) & (energ<energ_max )& bkg_pos_mask
    
            h_s, _ = np.histogram(seps[m_s]**2, bins=th2_bins)
            h_b, _ = np.histogram(seps_b[m_b]**2, bins=th2_bins)
            
            cts_s[i] += h_s
            cts_b[i] += h_b
    return cts_s, cts_b, t_expo

# %%
bkg_subtraction_radius = 0.4

cts_s_40deg, cts_b_40deg, t_expo_40deg = collect_data(hbus_40deg)
cts_s_20deg, cts_b_20deg, t_expo_20deg = collect_data(hbus_20deg)

print(f"Exposure time 40deg = {t_expo_40deg/60/60:.1f}h")
print(f"Exposure time 20deg = {t_expo_20deg/60/60:.1f}h")
# Out:
# Exposure time 40deg = 8.5h
# Exposure time 20deg = 9.3h

# %%
cts_40deg = cts_s_40deg - cts_b_40deg
cts_err_40deg = np.sqrt(cts_s_40deg + cts_b_40deg)

cts_20deg = cts_s_20deg - cts_b_20deg
cts_err_20deg = np.sqrt(cts_s_20deg + cts_b_20deg)

for i, ((cts_40, cts_err_40), (cts_20, cts_err_20)) in enumerate(zip(zip(cts_40deg, cts_err_40deg), zip(cts_20deg, cts_err_20deg))):
    plt.figure()
    plt.errorbar(th2, cts_40, cts_err_40, fmt='o', label='40°', color='blue')
    plt.errorbar(th2, cts_20, cts_err_20, fmt='s', label='20°', color='red')
    plt.axhline(0, color='black', linestyle='dotted')
    plt.xlim(0, 0.16)
    plt.title(str(round(e_mins[i],3)) + '-' + str(round(e_maxs[i],3)) + ' TeV')
    plt.xlabel(r'$\theta^2$, deg$^2$')
    plt.ylabel(r'$counts$')
    plt.legend()
    plt.show()

# %%
psf_hbu_40deg = irf_40deg["psf"]
psf_hbu_20deg = irf_20deg["psf"]

print(psf_hbu_40deg)
print(psf_hbu_40deg.info())
print(psf_hbu_40deg.data.shape)
# here i'm guessing the energy bins of the psf since idk how to see them.
psf_e_bins = np.logspace(np.log10(0.013), np.log10(199.526), 22)
psf_e_means = np.sqrt(psf_e_bins[1:]*psf_e_bins[:-1])
print(psf_e_bins)
# Out:
# EnergyDependentMultiGaussPSF
# ----------------------------
#
#   axes      : ['energy_true', 'offset']
#   shape     : (21, 6)
#   ndim      : 2
#   parameters: ['sigma_1', 'sigma_2', 'sigma_3', 'scale', 'ampl_2', 'ampl_3']
#
#
# Summary PSF info
# ----------------
# Theta          : size =     6, min =  0.500 deg, max =  5.500 deg
# Energy hi      : size =    21, min =  0.020 TeV, max = 199.526 TeV
# Energy lo      : size =    21, min =  0.013 TeV, max = 125.893 TeV
# 68.00 containment radius at offset = 0.0 deg and energy_true =  1.0 TeV: 0.074 deg
# 95.00 containment radius at offset = 0.0 deg and energy_true =  1.0 TeV: 0.121 deg
# 68.00 containment radius at offset = 0.0 deg and energy_true = 10.0 TeV: 0.062 deg
# 95.00 containment radius at offset = 0.0 deg and energy_true = 10.0 TeV: 0.100 deg
#
# (21, 6)
# [1.30000000e-02 2.05721347e-02 3.25548251e-02 5.15170959e-02
#  8.15243565e-02 1.29010003e-01 2.04154705e-01 3.23069084e-01
#  5.11247747e-01 8.09035193e-01 1.28027546e+00 2.02599994e+00
#  3.20608797e+00 5.07354412e+00 8.02874100e+00 1.27052570e+01
#  2.01057122e+01 3.18167246e+01 5.03490726e+01 7.96759926e+01
#  1.26085019e+02 1.99526000e+02]

# %%
sigmas_ext = [0.1, 0.2, 0.3, 0.4]

# %%
def calculate_UL(cts, cts_err, psf_hbu):
    flux_ratios = np.zeros((len(sigmas_ext), len(e)))
    
    for i, (ct, ct_err) in enumerate(zip(cts, cts_err)):
        ct_err += 0.0000001 # to dodge divide by zero
        # psf_index will store the best index for accessing the PSF values form the file.
        psf_index = np.argmin(np.abs(psf_e_means - e[i]))
        sigma_1, sigma_2, sigma_3, scale, ampl_2, ampl_3 = psf_hbu.data[psf_index][0]
    
        # Normalization of the PSF model to fit best the blazar
        def psf_model(th2):
            gauss1 = np.exp(-th2 / (2 * sigma_1**2))
            gauss2 = ampl_2*np.exp(-th2 / (2 * sigma_2**2))
            gauss3 = ampl_3*np.exp(-th2 / (2 * sigma_3**2))
            return (gauss1+gauss2+gauss3)

        # rescaling the psf component to match total counts of the data
        psf_component = psf_model(th2)
        psf_component = sum(ct)*psf_component/sum(psf_component)
        # The errors on the counts are independent, here I used this formula for error propagation:
        # z = \sum x_i, then z_err = sqrt(\sum x_i_err**2)
        # psf_component_err = np.sqrt(sum(ct_err**2))*psf_component/sum(psf_component) # THIS ERROR EXISTS IN THE FIRST PLACE???
        # Lets try without error
        psf_component_err = np.zeros_like(psf_component)
        chi2_noext = np.sum(((ct - psf_component)**2 / (ct_err**2 + psf_component_err**2)))
    
        # taken from andrii notebook, to fit with psf better:
        step=1.01
        chi2_noext_best=1e10
        adjust=1
        while(chi2_noext<chi2_noext_best):
            chi2_noext_best=chi2_noext
            
            chisq0=sum((ct-step*adjust*psf_component)**2/(ct_err**2+(step*adjust*psf_component_err)**2))
            chisq1=sum((ct-adjust*psf_component/step)**2/(ct_err**2+(adjust*psf_component_err/step)**2))
            chisq_vec=np.array([chisq0,chisq1])
            chi2_noext=min(chisq_vec)
            ind=np.argmin(chisq_vec)
            
            if(chi2_noext<chi2_noext_best):
                if(ind==0):
                    adjust*=step
                if(ind==1):
                    adjust/=step
                    
        psf_component *= adjust
        psf_component_err *= adjust
        chi2_noext = np.sum(((ct - psf_component)**2 / (ct_err**2 + psf_component_err**2)))
        
        fig, axs = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [2, 1]})
        fig.subplots_adjust(hspace=0)
        axs[0].errorbar(th2,ct,ct_err,linestyle='none',marker='o',label=name,color='black')
        axs[0].plot(th2,psf_component,color='black',linestyle='dashed',label='PSF')
        axs[0].fill_between(th2,(psf_component-psf_component_err),(psf_component+psf_component_err),color='black',alpha=0.1,linewidth=0)
        axs[0].set_title(str(round(e[i],3))+'-'+str(round(e[i],3))+r' TeV')
        axs[1].errorbar(th2,ct - psf_component,np.sqrt(ct_err**2+psf_component_err**2),marker='o',linestyle='none',color='black')
        axs[1].axhline(0,color='black',linestyle='dashed')
    
        # For each sigma_ext: add a gaussian term norm_ext*gauss(sigma_ext) convolved with the psf, to the point source model (psf only), until delta_chi2 is > 2.71.
        # With this you found norm_ext such that the fit breaks. Lets call this norm_ext_br
        # Then the upper limit to the detectable ext. emission should be given by an extended emission of the form of: norm_ext_br*gauss(sigma_ext).
        for k, sigma_ext in enumerate(sigmas_ext):
            def ext_model(th2):
                sigma1_conv = np.sqrt(sigma_1**2 + sigma_ext**2)
                sigma2_conv = np.sqrt(sigma_2**2 + sigma_ext**2)
                sigma3_conv = np.sqrt(sigma_3**2 + sigma_ext**2)
                gauss1_conv = np.exp(-th2 / (2 * sigma1_conv**2))
                gauss2_conv = ampl_2 * np.exp(-th2 / (2 * sigma2_conv**2))
                gauss3_conv = ampl_3 * np.exp(-th2 / (2 * sigma3_conv**2))
                return gauss1_conv + gauss2_conv + gauss3_conv
        
            ct_ext = ext_model(th2)
            ct_ext = sum(ct)*ct_ext/sum(ct_ext)
            ct_ext_plus_src = ct_ext+psf_component
            chi2_ext = np.sum(((ct - ct_ext_plus_src)**2 / (ct_err**2 + psf_component_err**2)))

            # Finding the best fit for psf*(extended + point)
            step=1.01
            chi2_ext_best = 1e10
            adjust_ext = 1
            adjust_point = 1
            while(chi2_ext < chi2_ext_best):
                chi2_ext_best = chi2_ext
                #ct_ext_err*=adjust_ext for the moment without error
                
                chisq0=sum((ct-step*adjust_point*psf_component-adjust_ext*ct_ext)**2/(ct_err**2+(step*adjust_point*psf_component_err)**2))
                chisq1=sum((ct-adjust_point*psf_component/step-adjust_ext*ct_ext)**2/(ct_err**2+(adjust_point*psf_component_err/step)**2))
                chisq2=sum((ct-adjust_point*psf_component-step*adjust_ext*ct_ext)**2/(ct_err**2+adjust_point*psf_component_err**2))
                chisq3=sum((ct-adjust_point*psf_component-adjust_ext*ct_ext/step)**2/(ct_err**2+adjust_point*psf_component_err**2))
                chisq_vec=np.array([chisq0,chisq1,chisq2,chisq3])
                chi2_ext=min(chisq_vec)
                ind=np.argmin(chisq_vec)
                
                if(chi2_ext<chi2_ext_best):
                    if(ind==0):
                        adjust_point*=step
                    if(ind==1):
                        adjust_point/=step
                    if(ind==2):
                        adjust_ext*=step
                    if(ind==3):
                        adjust_ext/=step

            ct_ext*=adjust_ext
            psf_component*=adjust_point
            psf_component_err*=adjust_point
            
            cts_tot_best = np.sum(ct_ext + psf_component)
            chi2_ext = np.sum(((ct - ct_ext - psf_component)**2 / (ct_err**2 + psf_component_err**2)))
            
            chi2_ext_best = chi2_ext
            ct_ext_best = ct_ext
            print(f"Best fit extended plus point gives chi2: {chi2_ext}")

            # Upper limits
            step=1.01
            chi2_ext_best = chi2_ext
            adjust_ext = 1
            adjust_point = 1
            while(chi2_ext < chi2_ext_best + 2.71):
                adjust_ext *= step
                ct_ext = ct_ext_best*adjust_ext
                chi2_ext = np.sum(((ct - psf_component - ct_ext)**2 / (ct_err**2 + psf_component_err**2)))

                chi2_ext_best_fixed_ext = 1e10
                while(chi2_ext < chi2_ext_best_fixed_ext):
                    chi2_ext_best_fixed_ext = chi2_ext
                    
                    chisq0=sum((ct-step*adjust_point*psf_component-ct_ext)**2/(ct_err**2+(step*adjust_point*psf_component_err)**2))
                    chisq1=sum((ct-adjust_point*psf_component/step-ct_ext)**2/(ct_err**2+(adjust_point*psf_component_err/step)**2))
                    chisq_vec=np.array([chisq0,chisq1])
                    chi2_ext=min(chisq_vec)
                    ind=np.argmin(chisq_vec)
                    
                    if(chi2_ext<chi2_ext_best_fixed_ext):
                        if(ind==0):
                            adjust_point*=step
                        if(ind==1):
                            adjust_point/=step

            flux_ratio = np.sum(ct_ext)/cts_tot_best
            flux_ratios[k][i] = flux_ratio
            axs[0].plot(th2,ct_ext,color='blue',alpha=0.5,linestyle='dashdot',label='extended source U.L.')
            
        plt.xlabel(r'$\theta^2$, deg$^2$')
        axs[0].set_ylabel('Counts')
        axs[0].legend()
        axs[0].set_yscale('log')
        plt.show()
    return flux_ratios

# %%
flux_ratios_40deg = calculate_UL(cts_40deg, cts_err_40deg, psf_hbu_40deg)
flux_ratios_20deg = calculate_UL(cts_20deg, cts_err_20deg, psf_hbu_20deg)
# Out:
# Best fit extended plus point gives chi2: 1.7660576385319533
# Best fit extended plus point gives chi2: 0.8876375491992322
# Best fit extended plus point gives chi2: 0.7168501481218117
# Best fit extended plus point gives chi2: 0.6931505960189017
# Best fit extended plus point gives chi2: 5.016220912938788
# Best fit extended plus point gives chi2: 4.949796712705266
# Best fit extended plus point gives chi2: 4.949796712705258
# Best fit extended plus point gives chi2: 4.949796712705215
# Best fit extended plus point gives chi2: 3.884254694203706
# Best fit extended plus point gives chi2: 3.8842546942036926
# Best fit extended plus point gives chi2: 3.884254694203686
# Best fit extended plus point gives chi2: 3.884254694203701
# Best fit extended plus point gives chi2: 2.6530649821924994
# Best fit extended plus point gives chi2: 2.653064982192525
# Best fit extended plus point gives chi2: 2.6530649821925056
# Best fit extended plus point gives chi2: 2.6530649821924976
# Best fit extended plus point gives chi2: 1.8362985891649724
# Best fit extended plus point gives chi2: 1.8362985891649692
# Best fit extended plus point gives chi2: 1.8362985891649672
# Best fit extended plus point gives chi2: 1.836298589164969
# Best fit extended plus point gives chi2: 1.8571108398571088
# Best fit extended plus point gives chi2: 1.8571108398571052
# Best fit extended plus point gives chi2: 1.8571108398571106
# Best fit extended plus point gives chi2: 1.8571108398570997
# Best fit extended plus point gives chi2: 4.675135719045848
# Best fit extended plus point gives chi2: 4.67513571904588
# Best fit extended plus point gives chi2: 4.675135719045878
# Best fit extended plus point gives chi2: 4.6751357190458585
# Best fit extended plus point gives chi2: 4.558146303170753
# Best fit extended plus point gives chi2: 4.55814630317076
# Best fit extended plus point gives chi2: 4.558146303170737
# Best fit extended plus point gives chi2: 4.558146303170725
# Best fit extended plus point gives chi2: 5.791445397270696
# Best fit extended plus point gives chi2: 5.791445397270635
# Best fit extended plus point gives chi2: 5.78532614057989
# Best fit extended plus point gives chi2: 5.752319313696558
# Best fit extended plus point gives chi2: 1.9779297926542616
# Best fit extended plus point gives chi2: 2.155612934206636
# Best fit extended plus point gives chi2: 2.215540318428637
# Best fit extended plus point gives chi2: 2.2164460870329927
# Best fit extended plus point gives chi2: 4.079502689238531
# Best fit extended plus point gives chi2: 3.4025589667223928
# Best fit extended plus point gives chi2: 3.5224878204928056
# Best fit extended plus point gives chi2: 3.62083538538763
# Best fit extended plus point gives chi2: 7.345197017528324
# Best fit extended plus point gives chi2: 8.170542961629453
# Best fit extended plus point gives chi2: 8.33173748772452
# Best fit extended plus point gives chi2: 8.331737487724581
# Best fit extended plus point gives chi2: 2.649944413352662
# Best fit extended plus point gives chi2: 2.4315106934613917
# Best fit extended plus point gives chi2: 2.29593353537832
# Best fit extended plus point gives chi2: 2.2323730833209194
# Best fit extended plus point gives chi2: 311269259589122.25
# Best fit extended plus point gives chi2: 189397840844130.22
# Best fit extended plus point gives chi2: 162716717149784.34
# Best fit extended plus point gives chi2: 154147141093501.84
# Best fit extended plus point gives chi2: 33765020245.821148
# Best fit extended plus point gives chi2: 5427225193125.77
# Best fit extended plus point gives chi2: 10576602395145.566
# Best fit extended plus point gives chi2: 12856786721743.41
# Best fit extended plus point gives chi2: 6.378787927273214
# Best fit extended plus point gives chi2: 6.37878792727318
# Best fit extended plus point gives chi2: 6.378787927273248
# Best fit extended plus point gives chi2: 6.378787927273245
# Best fit extended plus point gives chi2: 6.009033834456571
# Best fit extended plus point gives chi2: 6.43321243098109
# Best fit extended plus point gives chi2: 6.916722638551932
# Best fit extended plus point gives chi2: 7.132336329133754
# Best fit extended plus point gives chi2: 1.397916228367777
# Best fit extended plus point gives chi2: 1.418744900134505
# Best fit extended plus point gives chi2: 1.4187449001345036
# Best fit extended plus point gives chi2: 1.418744900134511
# Best fit extended plus point gives chi2: 4.667264332656299
# Best fit extended plus point gives chi2: 4.706398936762132
# Best fit extended plus point gives chi2: 4.698090826928755
# Best fit extended plus point gives chi2: 4.69126252780551
# Best fit extended plus point gives chi2: 4.503072387708372
# Best fit extended plus point gives chi2: 4.50307238770841
# Best fit extended plus point gives chi2: 4.503072387708427
# Best fit extended plus point gives chi2: 4.503072387708438
# Best fit extended plus point gives chi2: 8.842830712221328
# Best fit extended plus point gives chi2: 7.088440779180264
# Best fit extended plus point gives chi2: 6.142888467376735
# Best fit extended plus point gives chi2: 5.8315705035061045
# Best fit extended plus point gives chi2: 1.0534204404652752
# Best fit extended plus point gives chi2: 1.1128415005047898
# Best fit extended plus point gives chi2: 1.1128415005047867
# Best fit extended plus point gives chi2: 1.1128415005047994
# Best fit extended plus point gives chi2: 2.8446467194870317
# Best fit extended plus point gives chi2: 2.6289687182856585
# Best fit extended plus point gives chi2: 2.810120823969412
# Best fit extended plus point gives chi2: 2.8977095716865113
# Best fit extended plus point gives chi2: 4.330053306648518
# Best fit extended plus point gives chi2: 4.34410634657231
# Best fit extended plus point gives chi2: 4.34410634657233
# Best fit extended plus point gives chi2: 4.3441063465723175
# Best fit extended plus point gives chi2: 3.600047060081777
# Best fit extended plus point gives chi2: 3.6000470600817724
# Best fit extended plus point gives chi2: 3.6000470600817813
# Best fit extended plus point gives chi2: 3.600047060081784
# Best fit extended plus point gives chi2: 7.000019024708205
# Best fit extended plus point gives chi2: 7.00001902470825
# Best fit extended plus point gives chi2: 6.995106332040387
# Best fit extended plus point gives chi2: 6.962150297162833
# Best fit extended plus point gives chi2: 3.8993155350804214
# Best fit extended plus point gives chi2: 2.6448875691480787
# Best fit extended plus point gives chi2: 1.9433882691218751
# Best fit extended plus point gives chi2: 1.6823406294624803
# Best fit extended plus point gives chi2: 111096060800503.61
# Best fit extended plus point gives chi2: 389412227638114.0
# Best fit extended plus point gives chi2: 423097555386166.56
# Best fit extended plus point gives chi2: 429148735594957.9
# Best fit extended plus point gives chi2: 1.9999996000000597
# /tmp/ipykernel_465/1167225782.py:122: RuntimeWarning: invalid value encountered in multiply
#   ct_ext = ct_ext_best*adjust_ext
# Best fit extended plus point gives chi2: 1.9999996000000597
# Best fit extended plus point gives chi2: 1.9999996000000597
# Best fit extended plus point gives chi2: 1.9999996000000597
# Best fit extended plus point gives chi2: 7.9999989171574075
# Best fit extended plus point gives chi2: 7.9999989171574075
# Best fit extended plus point gives chi2: 7.9999989171574075
# Best fit extended plus point gives chi2: 7.9999989171574075

# %%
for i, (flux_ratio_40deg, flux_ratio_20deg) in enumerate(zip(flux_ratios_40deg, flux_ratios_20deg)):
    plt.errorbar(e*(0.95*1.03**i), flux_ratio_40deg,flux_ratio_40deg/3, alpha=0.2+0.2*i, uplims=True, linestyle='none',marker='o', label="40deg - "+str(round(sigmas_ext[i],3))+r'$^\circ$',color='blue')
    plt.errorbar(e*(0.95*1.03**i), flux_ratio_20deg,flux_ratio_20deg/3, alpha=0.2+0.2*i, uplims=True, linestyle='none',marker='o', label="20deg - "+str(round(sigmas_ext[i],3))+r'$^\circ$',color='red')
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r"$F_{ext}/F_{ps}$")
plt.xlabel("E [TeV]")
plt.xlim(0.04,11)
plt.legend()

# %%
def calculate_UL_merged(cts_40deg, cts_err_40deg, psf_hbu_40deg, cts_20deg, cts_err_20deg, psf_hbu_20deg):
    flux_ratios = np.zeros((len(sigmas_ext), len(e)))
    th2_extended = np.concatenate([th2, th2])
    
    for i, ((ct_40deg, ct_err_40deg), (ct_20deg, ct_err_20deg)) in enumerate(zip(zip(cts_40deg, cts_err_40deg), zip(cts_20deg, cts_err_20deg))):
        ct = np.concatenate([ct_40deg, ct_20deg])
        ct_err = np.concatenate([ct_err_40deg, ct_err_20deg])
        ct_err += 0.0000001
        # psf_index will store the best index for accessing the PSF values form the file.
        psf_index = np.argmin(np.abs(psf_e_means - e[i]))
        sigma_1_40deg, sigma_2_40deg, sigma_3_40deg, scale_40deg, ampl_2_40deg, ampl_3_40deg = psf_hbu_40deg.data[psf_index][0]
        sigma_1_20deg, sigma_2_20deg, sigma_3_20deg, scale_20deg, ampl_2_20deg, ampl_3_20deg = psf_hbu_20deg.data[psf_index][0]
        
        # Normalization of the PSF model to fit best the blazar
        def psf_model_40deg(th2):
            gauss1 = np.exp(-th2 / (2 * sigma_1_40deg**2))
            gauss2 = ampl_2_40deg * np.exp(-th2 / (2 * sigma_2_40deg**2))
            gauss3 = ampl_3_40deg * np.exp(-th2 / (2 * sigma_3_40deg**2))
            return scale_40deg*(gauss1 + gauss2 + gauss3)
         
        def psf_model_20deg(th2):
            gauss1 = np.exp(-th2 / (2 * sigma_1_20deg**2))
            gauss2 = ampl_2_20deg * np.exp(-th2 / (2 * sigma_2_20deg**2))
            gauss3 = ampl_3_20deg * np.exp(-th2 / (2 * sigma_3_20deg**2))
            return scale_20deg*(gauss1 + gauss2 + gauss3)

        psf_component_40deg = psf_model_40deg(th2)
        psf_component_20deg = psf_model_20deg(th2)
        psf_component = np.concatenate([psf_component_40deg, psf_component_20deg])

        # CHANGES FINISH FOR A WHILE
        
        # rescaling the psf component to match total counts of the data
        psf_component = sum(ct)*psf_component/sum(psf_component)
        # The errors on the counts are independent, here I used this formula for error propagation:
        # z = \sum x_i, then z_err = sqrt(\sum x_i_err**2)
        # psf_component_err = np.sqrt(sum(ct_err**2))*psf_component/sum(psf_component) # THIS ERROR EXISTS IN THE FIRST PLACE???
        psf_component_err = np.zeros_like(psf_component)
        chi2_noext = np.sum(((ct - psf_component)**2 / (ct_err**2 + psf_component_err**2)))
    
        # taken from andrii notebook, to fit with psf better:
        step=1.01
        chi2_noext_best=1e10
        adjust=1
        while(chi2_noext<chi2_noext_best):
            chi2_noext_best=chi2_noext
            
            chisq0=sum((ct-step*adjust*psf_component)**2/(ct_err**2+(step*adjust*psf_component_err)**2))
            chisq1=sum((ct-adjust*psf_component/step)**2/(ct_err**2+(adjust*psf_component_err/step)**2))
            chisq_vec=np.array([chisq0,chisq1])
            chi2_noext=min(chisq_vec)
            ind=np.argmin(chisq_vec)
            
            if(chi2_noext<chi2_noext_best):
                if(ind==0):
                    adjust*=step
                if(ind==1):
                    adjust/=step
                    
        psf_component *= adjust
        psf_component_err *= adjust
        chi2_noext = np.sum(((ct - psf_component)**2 / (ct_err**2 + psf_component_err**2)))

        fig, axs = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [2, 1]})
        fig.subplots_adjust(hspace=0)
        axs[0].errorbar(th2_extended,ct,ct_err,linestyle='none',marker='o',label=name,color='black')
        axs[0].plot(th2_extended,psf_component,color='black',linestyle='dashed',label='PSF')
        axs[0].fill_between(th2_extended,(psf_component-psf_component_err),(psf_component+psf_component_err),color='black',alpha=0.1,linewidth=0)
        axs[0].set_title(str(round(e[i],3))+'-'+str(round(e[i],3))+r' TeV')
        axs[1].errorbar(th2_extended,ct - psf_component,np.sqrt(ct_err**2+psf_component_err**2),marker='o',linestyle='none',color='black')
        axs[1].axhline(0,color='black',linestyle='dashed')
    
        # For each sigma_ext: add a gaussian term norm_ext*gauss(sigma_ext) convolved with the psf, to the point source model (psf only), until delta_chi2 is > 2.71.
        # With this you found norm_ext such that the fit breaks. Lets call this norm_ext_br
        # Then the upper limit to the detectable ext. emission should be given by an extended emission of the form of: norm_ext_br*gauss(sigma_ext).
        for k, sigma_ext in enumerate(sigmas_ext):
            
            # CHANGES CONTINUE
            
            def ext_model_40deg(th2):
                sigma1_conv = np.sqrt(sigma_1_40deg**2 + sigma_ext**2)
                sigma2_conv = np.sqrt(sigma_2_40deg**2 + sigma_ext**2)
                sigma3_conv = np.sqrt(sigma_3_40deg**2 + sigma_ext**2)
                gauss1_conv = np.exp(-th2 / (2 * sigma1_conv**2))
                gauss2_conv = ampl_2_40deg * np.exp(-th2 / (2 * sigma2_conv**2))
                gauss3_conv = ampl_3_40deg * np.exp(-th2 / (2 * sigma3_conv**2))
                return scale_40deg*(gauss1_conv + gauss2_conv + gauss3_conv)

            def ext_model_20deg(th2):
                sigma1_conv = np.sqrt(sigma_1_20deg**2 + sigma_ext**2)
                sigma2_conv = np.sqrt(sigma_2_20deg**2 + sigma_ext**2)
                sigma3_conv = np.sqrt(sigma_3_20deg**2 + sigma_ext**2)
                gauss1_conv = np.exp(-th2 / (2 * sigma1_conv**2))
                gauss2_conv = ampl_2_20deg * np.exp(-th2 / (2 * sigma2_conv**2))
                gauss3_conv = ampl_3_20deg * np.exp(-th2 / (2 * sigma3_conv**2))
                return scale_20deg*(gauss1_conv + gauss2_conv + gauss3_conv)

            ct_ext_40deg = ext_model_40deg(th2)
            ct_ext_20deg = ext_model_20deg(th2)
            
            ct_ext = np.concatenate([ct_ext_40deg, ct_ext_20deg])
            ct_ext = sum(ct)*ct_ext/sum(ct_ext)
            ct_ext_plus_src = ct_ext+psf_component
            chi2_ext = np.sum(((ct - ct_ext_plus_src)**2 / (ct_err**2 + psf_component_err**2)))

            # Finding the best fit for psf*(extended + point)
            step=1.01
            chi2_ext_best = 1e10
            adjust_ext = 1
            adjust_point = 1
            while(chi2_ext < chi2_ext_best):
                chi2_ext_best = chi2_ext
                #ct_ext_err*=adjust_ext for the moment without error
                
                chisq0=sum((ct-step*adjust_point*psf_component-adjust_ext*ct_ext)**2/(ct_err**2+(step*adjust_point*psf_component_err)**2))
                chisq1=sum((ct-adjust_point*psf_component/step-adjust_ext*ct_ext)**2/(ct_err**2+(adjust_point*psf_component_err/step)**2))
                chisq2=sum((ct-adjust_point*psf_component-step*adjust_ext*ct_ext)**2/(ct_err**2+adjust_point*psf_component_err**2))
                chisq3=sum((ct-adjust_point*psf_component-adjust_ext*ct_ext/step)**2/(ct_err**2+adjust_point*psf_component_err**2))
                chisq_vec=np.array([chisq0,chisq1,chisq2,chisq3])
                chi2_ext=min(chisq_vec)
                ind=np.argmin(chisq_vec)
                
                if(chi2_ext<chi2_ext_best):
                    if(ind==0):
                        adjust_point*=step
                    if(ind==1):
                        adjust_point/=step
                    if(ind==2):
                        adjust_ext*=step
                    if(ind==3):
                        adjust_ext/=step

            ct_ext*=adjust_ext
            psf_component*=adjust_point
            psf_component_err*=adjust_point
            
            cts_tot_best = np.sum(ct_ext + psf_component)
            chi2_ext = np.sum(((ct - ct_ext - psf_component)**2 / (ct_err**2 + psf_component_err**2)))
            
            chi2_ext_best = chi2_ext
            ct_ext_best = ct_ext
            print(f"Best fit extended plus point gives chi2: {chi2_ext}")

            # Upper limits
            step=1.01
            chi2_ext_best = chi2_ext
            adjust_ext = 1
            adjust_point = 1
            while(chi2_ext < chi2_ext_best + 2.71):
                adjust_ext *= step
                ct_ext = ct_ext_best*adjust_ext
                chi2_ext = np.sum(((ct - psf_component - ct_ext)**2 / (ct_err**2 + psf_component_err**2)))

                chi2_ext_best_fixed_ext = 1e10
                while(chi2_ext < chi2_ext_best_fixed_ext):
                    chi2_ext_best_fixed_ext = chi2_ext
                    
                    chisq0=sum((ct-step*adjust_point*psf_component-ct_ext)**2/(ct_err**2+(step*adjust_point*psf_component_err)**2))
                    chisq1=sum((ct-adjust_point*psf_component/step-ct_ext)**2/(ct_err**2+(adjust_point*psf_component_err/step)**2))
                    chisq_vec=np.array([chisq0,chisq1])
                    chi2_ext=min(chisq_vec)
                    ind=np.argmin(chisq_vec)
                    
                    if(chi2_ext<chi2_ext_best_fixed_ext):
                        if(ind==0):
                            adjust_point*=step
                        if(ind==1):
                            adjust_point/=step

            flux_ratio = np.sum(ct_ext)/cts_tot_best
            flux_ratios[k][i] = flux_ratio
            axs[0].plot(th2_extended,ct_ext,color='blue',alpha=0.5,linestyle='dashdot',label='extended source U.L.')
            
        plt.xlabel(r'$\theta^2$, deg$^2$')
        axs[0].set_ylabel('Counts')
        axs[0].legend()
        axs[0].set_yscale('log')
        plt.show()
    return flux_ratios

# %%
flux_ratios = calculate_UL_merged(cts_40deg, cts_err_40deg, psf_hbu_40deg, cts_20deg, cts_err_20deg, psf_hbu_20deg)
# Out:
# Best fit extended plus point gives chi2: 10.688918108069405
# Best fit extended plus point gives chi2: 10.590309635812066
# Best fit extended plus point gives chi2: 10.590309635812087
# Best fit extended plus point gives chi2: 10.590309635812169
# Best fit extended plus point gives chi2: 11.924657733380023
# Best fit extended plus point gives chi2: 12.275214959659456
# Best fit extended plus point gives chi2: 12.398238404129987
# Best fit extended plus point gives chi2: 12.46430011344781
# Best fit extended plus point gives chi2: 7.055473727311391
# Best fit extended plus point gives chi2: 6.935913685486881
# Best fit extended plus point gives chi2: 6.935913685486968
# Best fit extended plus point gives chi2: 6.93591368548688
# Best fit extended plus point gives chi2: 22.457782181800123
# Best fit extended plus point gives chi2: 24.774346724473705
# Best fit extended plus point gives chi2: 24.895277171546052
# Best fit extended plus point gives chi2: 24.92099239129798
# Best fit extended plus point gives chi2: 102.48766611940182
# Best fit extended plus point gives chi2: 132.68006238847394
# Best fit extended plus point gives chi2: 133.57486849885504
# Best fit extended plus point gives chi2: 133.60230789762198
# Best fit extended plus point gives chi2: 198.89434490241266
# Best fit extended plus point gives chi2: 300.2298297047526
# Best fit extended plus point gives chi2: 310.832268907079
# Best fit extended plus point gives chi2: 313.80547893494634
# Best fit extended plus point gives chi2: 212.15272402760627
# Best fit extended plus point gives chi2: 336.1141779372764
# Best fit extended plus point gives chi2: 346.6270630977381
# Best fit extended plus point gives chi2: 348.9945111614436
# Best fit extended plus point gives chi2: 174.30710870192416
# Best fit extended plus point gives chi2: 261.5349623692079
# Best fit extended plus point gives chi2: 269.80405125179817
# Best fit extended plus point gives chi2: 271.86435694427877
# Best fit extended plus point gives chi2: 158.4976918003517
# Best fit extended plus point gives chi2: 230.49828112301137
# Best fit extended plus point gives chi2: 233.99211227397615
# Best fit extended plus point gives chi2: 234.5032708315304
# Best fit extended plus point gives chi2: 75.67856115418294
# Best fit extended plus point gives chi2: 95.1100428379703
# Best fit extended plus point gives chi2: 96.07045045391415
# Best fit extended plus point gives chi2: 96.2870602820836
# Best fit extended plus point gives chi2: 43.793182091879856
# Best fit extended plus point gives chi2: 54.98512081158841
# Best fit extended plus point gives chi2: 55.63704574425511
# Best fit extended plus point gives chi2: 55.82170159676398
# Best fit extended plus point gives chi2: 11.943510915498852
# Best fit extended plus point gives chi2: 16.20484471761666
# Best fit extended plus point gives chi2: 17.32643064862004
# Best fit extended plus point gives chi2: 17.732356496725167
# Best fit extended plus point gives chi2: 1049081128198.4954
# Best fit extended plus point gives chi2: 3872917585231.615
# Best fit extended plus point gives chi2: 4238085927417.0845
# Best fit extended plus point gives chi2: 4305309781230.4155
# Best fit extended plus point gives chi2: 43228091349645.516
# Best fit extended plus point gives chi2: 33714645589770.29
# Best fit extended plus point gives chi2: 31588301141687.28
# Best fit extended plus point gives chi2: 30924186690461.52
# Best fit extended plus point gives chi2: 11.999996468532927
# Best fit extended plus point gives chi2: 699697941271.9507
# Best fit extended plus point gives chi2: 1378265363467.5828
# Best fit extended plus point gives chi2: 1677957411720.797

# %%
for i, flux_ratio in enumerate(flux_ratios):
    plt.errorbar(e*(0.95*1.03**i), flux_ratio,flux_ratio/3, alpha=0.2+0.2*i, uplims=True, linestyle='none',marker='o', label="40deg - "+str(round(sigmas_ext[i],3))+r'$^\circ$',color='black')
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r"$F_{ext}/F_{ps}$")
plt.xlabel("E [TeV]")
plt.xlim(0.04,11)
plt.ylim(0.01, 1)
plt.legend()
plt.show()

for i, (flux_ratio_40deg, flux_ratio_20deg) in enumerate(zip(flux_ratios_40deg, flux_ratios_20deg)):
    plt.errorbar(e*(0.95*1.03**i), flux_ratio_40deg,flux_ratio_40deg/3, alpha=0.2+0.2*i, uplims=True, linestyle='none',marker='o', label="40deg - "+str(round(sigmas_ext[i],3))+r'$^\circ$',color='blue')
    plt.errorbar(e*(0.95*1.03**i), flux_ratio_20deg,flux_ratio_20deg/3, alpha=0.2+0.2*i, uplims=True, linestyle='none',marker='o', label="20deg - "+str(round(sigmas_ext[i],3))+r'$^\circ$',color='red')
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r"$F_{ext}/F_{ps}$")
plt.xlabel("E [TeV]")
plt.xlim(0.04,11)
plt.ylim(0.01, 1)
plt.legend()

# %%
flux_ratios
# Out:
# array([[2.43441351e-01, 2.48625044e-01, 9.03645522e-02, 1.70157043e-01,
#         3.05945052e-01, 4.86791544e-01, 5.60553967e-01, 5.34373731e-01,
#         6.18893932e-01, 4.83306351e-01, 6.11976327e-01, 8.29061109e-01,
#         1.01000000e+00, 5.05000000e-01, 1.67648986e+05],
#        [1.30052401e-01, 1.36481681e-01, 3.97992506e-02, 7.42691494e-02,
#         8.46174413e-02, 2.23046877e-01, 2.12756891e-01, 2.13710291e-01,
#         1.92864001e-01, 1.91555124e-01, 2.91779919e-01, 6.52697291e-01,
#         1.01000000e+00, 5.05000000e-01, 1.01000000e+00],
#        [1.09813320e-01, 1.13592410e-01, 3.32728626e-02, 6.12302369e-02,
#         5.61034313e-02, 1.81930133e-01, 1.50200248e-01, 1.57430623e-01,
#         1.26694769e-01, 1.58575389e-01, 2.47890975e-01, 6.03939026e-01,
#         1.01000000e+00, 5.05000000e-01, 1.01000000e+00],
#        [1.03449114e-01, 1.05130645e-01, 3.10341997e-02, 5.61061536e-02,
#         4.71344288e-02, 1.65729105e-01, 1.28570350e-01, 1.35905704e-01,
#         1.05922644e-01, 1.46471020e-01, 2.31663025e-01, 5.84945228e-01,
#         1.01000000e+00, 5.05000000e-01, 1.01000000e+00]])
