# %%
import os

import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
from astropy.coordinates import SkyCoord
from astropy.io import fits
from gammapy.irf import load_irf_dict_from_file
from scipy.stats import chi2, poisson

# %%
mrk421_coord = SkyCoord.from_name("Mrk 421")
es0229_coord = SkyCoord.from_name("1ES 0229+200")

# TOCOMPLETE: HBUs datas folder
mrk421_folder = "../data/mrk_421/"
es0229_folder = "../data/1ES_0229+200/"
# TOCOMPLETE: IRF file
irf_file = "../data/irfs/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits.gz"

# %% [markdown]
# **Choose here between Mrk 421 and 1ES 0229+200**

# %%
mrk421_choice = True

if mrk421_choice:
    blazar_coord = mrk421_coord
    data_folder = mrk421_folder
else:
    blazar_coord = es0229_coord
    data_folder = es0229_folder


blazar_l = blazar_coord.galactic.l.deg
blazar_b = blazar_coord.galactic.b.deg

hbus = []
for filename in os.listdir(data_folder):
    hbus.append(fits.open(data_folder + filename))

irf = load_irf_dict_from_file(irf_file)
aeff = irf["aeff"]

# %% [markdown]
# **Data collecting and overview**

# %%
# Source - background cake angle
src_angle = 0.2
# Extended emission angle
ext_angle = 0.25

data = {
    "src_energy": np.array([]),
    "ext_src_energy": np.array([]),
    "src_sep": np.array([]),
    "bkg_energy": np.array([]),
    "ext_bkg_energy": np.array([]),
    "all_coords_l": np.array([]),
    "all_coords_b": np.array([]),
    "all_energies": np.array([]),
    "all_sep": np.array([]),
    "offsets": np.array([]),
    "t_tot": np.array([]),
}

for hbu in hbus:
    data_raw = hbu["EVENTS"].data

    coord = SkyCoord(
        ra=data_raw["RA"] * u.deg, dec=data_raw["DEC"] * u.deg, frame="icrs"
    )

    pointing_coord = SkyCoord(
        ra=hbu[1].header["RA_PNT"] * u.deg,
        dec=hbu[1].header["DEC_PNT"] * u.deg,
        frame="icrs",
    )

    bkg_center = SkyCoord(
        l=2 * pointing_coord.galactic.l - blazar_coord.galactic.l,
        b=2 * pointing_coord.galactic.b - blazar_coord.galactic.b,
        frame="galactic",
    )

    src_pos_mask = coord.separation(blazar_coord).degree < src_angle
    bkg_pos_mask = coord.separation(bkg_center).degree < src_angle
    ext_src_pos_mask = coord.separation(blazar_coord).degree > ext_angle
    ext_bkg_pos_mask = coord.separation(bkg_center).degree > ext_angle

    t = data_raw["TIME"]
    t = np.sort(t)
    t_tot = t[-1] - t[0]

    data["src_energy"] = np.concatenate(
        [data["src_energy"], data_raw["ENERGY_TRUE"][src_pos_mask]]
    )

    data["ext_src_energy"] = np.concatenate(
        [
            data["ext_src_energy"],
            data_raw["ENERGY_TRUE"][src_pos_mask * ext_src_pos_mask],
        ]
    )

    data["src_sep"] = np.concatenate(
        [data["src_sep"], coord[src_pos_mask].separation(blazar_coord).degree]
    )

    data["all_coords_l"] = np.concatenate([data["all_coords_l"], coord.galactic.l.deg])
    data["all_coords_b"] = np.concatenate([data["all_coords_b"], coord.galactic.b.deg])
    data["all_energies"] = np.concatenate([data["all_energies"], data_raw["ENERGY"]])
    data["all_sep"] = np.concatenate(
        [data["all_sep"], coord.separation(blazar_coord).degree]
    )
    data["offsets"] = np.concatenate(
        [data["offsets"], [pointing_coord.separation(blazar_coord).degree]]
    )
    data["t_tot"] = np.concatenate([data["t_tot"], [t_tot]])

print(f"Near source events: {len(data['src_energy'])}")
print(f"Background events: {len(data['bkg_energy'])}")
print(f"Total events: {len(data['all_energies'])}")
# Out:
# Near source events: 98567
# Background events: 0
# Total events: 3335834

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Data overview
counts, xedges, yedges, im = ax1.hist2d(
    data["all_coords_l"],
    data["all_coords_b"],
    bins=100,
    range=[[blazar_l - 1, blazar_l + 1], [blazar_b - 1, blazar_b + 1]],
    cmap="viridis",
)
ax1.scatter(
    blazar_l, blazar_b, marker="x", color="red", s=200, linewidth=0.5, label="Blazar"
)
ax1.set_xlabel("Galactic Longitude [deg]")
ax1.set_ylabel("Galactic Latitude [deg]")
ax1.set_title("Data overview")
ax1.legend()

# Radial distribution
radial_bins = np.linspace(0, 3, 50)
radial_counts, bin_edges = np.histogram(data["all_sep"], bins=radial_bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Normalize by area
areas = np.pi * (bin_edges[1:] ** 2 - bin_edges[:-1] ** 2)
density = radial_counts / areas
ax2.plot(bin_centers, density, marker="+", color="red", linewidth=2)
ax2.set_xlabel("Distance from Blazar [deg]")
ax2.set_ylabel(r"Event Density [deg$^{-2}$]")
ax2.set_title("Radial Event Density Profile")
ax2.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# **Background removal and source power approximation**

# %%
# For 1ES 0229+200 there is not a lot of data. It is better to set fewer energy bins.
energy_bins = np.logspace(-1, 1, 20)
bin_edges = energy_bins
bin_centers = (energy_bins[:-1] + energy_bins[1:]) / 2

src_counts, _ = np.histogram(data["src_energy"], bins=energy_bins)
bkg_counts, _ = np.histogram(data["bkg_energy"], bins=energy_bins)
net_counts = src_counts - bkg_counts

# Considering a Poisson distribution.
src_errors = np.sqrt(src_counts)
bkg_errors = np.sqrt(bkg_counts)
net_errors = np.sqrt(src_counts + bkg_counts)

# %%
# Source SED approximation
blazar_offset = np.mean(data["offsets"])
dE = energy_bins[1:] - energy_bins[:-1]
exposure_time = np.sum(data["t_tot"])
effective_area = (
    aeff.evaluate(energy_true=bin_centers * u.TeV, offset=blazar_offset * u.deg)
    .to(u.cm**2)
    .value
)
sed_points = net_counts * (bin_centers**2) / (exposure_time * effective_area * dE)
sed_errors = net_errors * (bin_centers**2) / (exposure_time * effective_area * dE)

# %%
# Source SED upper bound approximation
confidence_level = 0.95
z_value = scipy.stats.norm.ppf(confidence_level)


# Calculate upper limits using chi-squared method
def calculate_upper_limit(n_obs, bkg, confidence_level=0.95):
    alpha = 1 - confidence_level
    if n_obs > 0:
        ul = 0.5 * chi2.ppf(confidence_level, 2 * (n_obs + 1)) - bkg
    else:
        ul = -np.log(alpha) - bkg
    return max(0, ul)


upper_limits = np.array(
    [
        calculate_upper_limit(src_counts[i], bkg_counts[i], 0.95)
        for i in range(len(src_counts))
    ]
)
sed_upper_limits = (
    upper_limits * (bin_centers**2) / (exposure_time * effective_area * dE)
)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 8), sharex=True)

# Displaying source & background counts
ax1.errorbar(
    bin_centers,
    src_counts,
    yerr=src_errors,
    fmt="o",
    color="red",
    markersize=4,
    linewidth=2,
    label="Source",
    capsize=3,
    alpha=0.8,
)
ax1.errorbar(
    bin_centers,
    bkg_counts,
    yerr=bkg_errors,
    fmt="o",
    color="blue",
    markersize=4,
    linewidth=2,
    label="Background",
    capsize=3,
    alpha=0.8,
)
ax1.set_yscale("log")
ax1.set_xscale("log")
ax1.set_ylabel("Counts")
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_title("Spectral Analysis: Source vs Background Counts")

# Displaying (source - background) counts
ax2.errorbar(
    bin_centers,
    net_counts,
    yerr=net_errors,
    fmt="o",
    color="black",
    markersize=5,
    linewidth=2,
    label="Net Counts",
    capsize=4,
    alpha=0.8,
)
ax2.set_xscale("log")
ax2.set_xlabel("Energy [TeV]")
ax2.set_ylabel("Net Counts (Source $-$ Background)")
ax2.legend()
ax2.grid(True, alpha=0.3)

# Displaying SED
ax3.errorbar(
    bin_centers,
    sed_points,
    yerr=sed_errors,
    fmt="o",
    color="black",
    markersize=5,
    linewidth=2,
    label="SED Approximation",
    capsize=4,
    alpha=0.8,
)
ax3.plot(
    bin_centers,
    sed_upper_limits,
    color="gray",
    linewidth=2,
    linestyle="--",
    label="Upper Limit",
)
ax3.fill_between(bin_centers, 0, sed_upper_limits, color="gray", alpha=0.3)
ax3.set_xscale("log")
ax3.set_yscale("log")
ax3.set_xlabel("Energy [TeV]")
ax3.set_ylabel(r"$E^2 dN/dE$ [TeV cm$^{-2}$ s$^{-1}$]")
ax3.legend()
ax3.grid(True, alpha=0.3)
ax3.set_title("Spectral Energy Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Statistical tests for source detection**

# %%
# Statistical tests for source detection
t_stat, p_value = scipy.stats.ttest_1samp(net_counts, 0)

total_background = np.sum(bkg_counts)
total_observed = np.sum(src_counts)
p_value_poisson = 1 - poisson.cdf(total_observed - 1, total_background)

print(f"T-test: t = {t_stat:.3f}, p = {p_value:.3f}")
print(f"Poisson test: p = {p_value_poisson:.3e}")
# Out:
# T-test: t = 4.037, p = 0.001
# Poisson test: p = 0.000e+00

# %% [markdown]
# **Angular SED**

# %%
ANGLE_BINS = np.linspace(0.0, 0.13, 20)
ENERGY_RANGES = [(0.5, 1.5), (1.5, 4.0)]

angle_bin_centers = (ANGLE_BINS[1:] + ANGLE_BINS[:-1]) / 2
exposure_time = np.sum(data["t_tot"])
blazar_offset = np.mean(data["offsets"])


def calculate_angular_sed_for_range(E_min, E_max):
    dE = E_max - E_min
    E_mean = (E_max + E_min) / 2

    energy_mask = (data["all_energies"] > E_min) & (data["all_energies"] < E_max)

    counts_per_bin = []

    for i in range(len(ANGLE_BINS) - 1):
        angle_mask = (data["all_sep"] ** 2 >= ANGLE_BINS[i]) & (
            data["all_sep"] ** 2 < ANGLE_BINS[i + 1]
        )
        counts = np.sum(angle_mask & energy_mask)
        counts_per_bin.append(counts)

    counts_per_bin = np.array(counts_per_bin)

    # TODO: use a better effective area, dont use center of angle**2 bin.
    effective_areas = np.array(
        [
            aeff.evaluate(energy_true=E_mean * u.TeV, offset=np.sqrt(angle_sq) * u.deg)
            .to(u.cm**2)
            .value
            for angle_sq in angle_bin_centers
        ]
    )

    sed_values = counts_per_bin * (E_mean**2) / (exposure_time * effective_areas * dE)
    sed_errors = sed_values / np.sqrt(np.maximum(counts_per_bin, 1))

    return sed_values, sed_errors

# %%
for E_min, E_max in ENERGY_RANGES:
    sed_values, sed_errors = calculate_angular_sed_for_range(E_min, E_max)

    plt.errorbar(
        angle_bin_centers,
        sed_values,
        yerr=sed_errors,
        fmt=".",
        markersize=6,
        linewidth=1.5,
        capsize=3,
        alpha=0.8,
        label=rf"$E\in[{E_min}, {E_max}]$",
    )

plt.yscale("log")
plt.xlabel(r"Distance squared [deg$^2$]")
plt.ylabel(r"$E^2 dN/dE$ [TeV cm$^{-2}$ s$^{-1}$]")
plt.title("Angular SED")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# For the vale of the theoretical bkg flux at different energies:
# D. Kerszberg, M. Kraus and e.a. Kolitzus D., The cosmic-ray electron spectrum measured with H.E.S.S., .

bkg_th_en_low = 0.5  # [TeV]
bkg_th_en_high = 1.5  # [TeV]

bkg_flux_th_low = 1.5e-3  # [m^-2 * s^-1 * sr^-1 * TeV^-1]
bkg_flux_th_high = 2.0e-5  # [m^-2 * s^-1 * sr^-1 * TeV^-1]

delta_angle_sq = ANGLE_BINS[1] - ANGLE_BINS[0]
omega_bin = delta_angle_sq * (u.deg**2).to(u.sr)

bkg_sed_th_low = bkg_flux_th_low * (1e-2) ** 2 * bkg_th_en_low**2 * omega_bin
bkg_sed_th_high = bkg_flux_th_high * (1e-2) ** 2 * bkg_th_en_high**2 * omega_bin

print(f"0.5 TeV: {bkg_sed_th_low}, 1.5 TeV: {bkg_sed_th_high}")
# Out:
# 0.5 TeV: 7.815841691895814e-14, 1.5 TeV: 9.379010030274977e-15

# %% [markdown]
# **Comparing with Korochkin paper data**

# %%
corchkin_src = np.genfromtxt(
    "../data/corchkin_05_105TeV_blk_line.csv", delimiter=",", skip_header=1
)
corchkin_src = np.append(corchkin_src[:, 1], np.zeros(10))
corchkin_red = np.genfromtxt(
    "../data/corchkin_05_105TeV_red_line.csv", delimiter=",", skip_header=1
)
corchkin_red = corchkin_red[:, 1]
corchkin_green = np.genfromtxt(
    "../data/corchkin_05_105TeV_gre_line.csv", delimiter=",", skip_header=1
)
corchkin_green = corchkin_green[:, 1]
corchkin_blue = np.genfromtxt(
    "../data/corchkin_05_105TeV_blu_line.csv", delimiter=",", skip_header=1
)
corchkin_blue = corchkin_blue[:, 1]
corchkin_bkg = 4e-14

# %%
E_min, E_max = ENERGY_RANGES[0]
sed_values, sed_errors = calculate_angular_sed_for_range(E_min, E_max)

plt.errorbar(
    angle_bin_centers,
    sed_values,
    yerr=sed_errors,
    fmt=".",
    markersize=6,
    linewidth=1.5,
    capsize=3,
    alpha=0.8,
    label="CTAO 1DC",
)

plt.plot(angle_bin_centers, corchkin_src, "k+-", label="primary signal from paper")
plt.plot(
    angle_bin_centers,
    corchkin_red,
    "r+-",
    label=rf"ext. emission with  $B=1e-11$G from paper",
)
plt.plot(
    angle_bin_centers,
    corchkin_green,
    "g+-",
    label=rf"ext. emission with  $B=1e-12$G from paper",
)
plt.plot(
    angle_bin_centers,
    corchkin_bkg * angle_bin_centers**0,
    "k:",
    label="bkg data from HESS",
)

plt.yscale("log")
plt.xlabel(r"Distance squared [deg$^2$]")
plt.ylabel(r"$E^2 dN/dE$ [TeV cm$^{-2}$ s$^{-1}$]")
plt.title(rf"Comparison with paper (ref) $E\in[{E_min}, {E_max}]$")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fitting CTAO 1DC data with a sum of the components from the paper with different normalizations**

# %%
def fit_model(ext_data, angle_centers, src_norm, bkg_norm, ext_norm):
    src = src_norm * corchkin_src
    bkg = bkg_norm * corchkin_bkg
    ext = ext_norm * ext_data
    return src + bkg + ext

# %%
from scipy.optimize import curve_fit

ext_data = corchkin_green

init_guess = [1.0, 1.0, 1.0]


def fit_function(angle_centers, bkg_norm, src_norm, ext_norm):
    return fit_model(ext_data, angle_centers, src_norm, bkg_norm, ext_norm)


popt, pcov = curve_fit(
    fit_function,
    angle_bin_centers,
    sed_values,
    sigma=sed_errors,
    p0=init_guess,
    absolute_sigma=True,
)

bkg_norm_fit, src_norm_fit, ext_norm_fit = popt
bkg_norm_err, src_norm_err, ext_norm_err = np.sqrt(np.diag(pcov))
fit = fit_function(angle_bin_centers, *popt)

print(rf"Background normalization: {bkg_norm_fit:.3f} $\pm$ {bkg_norm_err:.3f}")
print(rf"Source normalization: {src_norm_fit:.3f} $\pm$ {src_norm_err:.3f}")
print(rf"Ext. emission normalization: {ext_norm_fit:.3f} $\pm$ {ext_norm_err:.3f}")
# Out:
# Background normalization: 3.533 $\pm$ 0.334
# Source normalization: 2.570 $\pm$ 0.057
# Ext. emission normalization: 2.842 $\pm$ 1.143

# %%
chi2_value = np.sum(((sed_values - fit) / sed_errors) ** 2)
ndof = len(sed_values) - 3
p_value = 1 - chi2.cdf(chi2_value, ndof)

print(f"chi2 = {chi2_value:.3f}")
print(f"chi2/ndof = {chi2_value / ndof:.3f} (ndof = {ndof})")
print(f"p-value = {p_value:.3f}")
# Out:
# chi2 = 56.083
# chi2/ndof = 3.505 (ndof = 16)
# p-value = 0.000

# %% [markdown]
# **Comparison with the same model without extended emission**

# %%
def model_no_extended(angle_centers, bkg_norm, src_norm):
    return bkg_norm * corchkin_bkg + src_norm * corchkin_src


popt_no_ext, pcov_no_ext = curve_fit(
    model_no_extended,
    angle_bin_centers,
    sed_values,
    sigma=sed_errors,
    p0=[1.0, 1.0],
    absolute_sigma=True,
)

fit_no_ext = model_no_extended(angle_bin_centers, *popt_no_ext)
chi2_no_ext = np.sum(((sed_values - fit_no_ext) / sed_errors) ** 2)
ndof_no_ext = len(sed_values) - 2

print(f"chi2/ndof without extended: {chi2_no_ext / ndof_no_ext:.3f}")
print(f"chi2/ndof with extended: {chi2_value / ndof:.3f}")
# Out:
# chi2/ndof without extended: 3.663
# chi2/ndof with extended: 3.505

# %%
def f_test_nested(chi2_simple, ndof_simple, chi2_complex, ndof_complex):
    F = ((chi2_simple - chi2_complex) / (ndof_simple - ndof_complex)) / (
        chi2_complex / ndof_complex
    )
    p_value = 1 - chi2.cdf(F, ndof_simple - ndof_complex)
    return F, p_value


F_value, p_value_F = f_test_nested(chi2_no_ext, ndof_no_ext, chi2_value, ndof)

print(f"F-TEST")
print(f"F-value: {F_value:.3f}")
print(f"p-value: {p_value_F:.3f}")

if p_value_F < 0.05:
    print("Extended emission statistically significant (p < 0.05)")
elif p_value_F < 0.10:
    print("Extended emission marginally significant (p < 0.10)")
else:
    print("Extended emission not statistically significant")
# Out:
# F-TEST
# F-value: 1.764
# p-value: 0.184
# Extended emission not statistically significant

# %%
plt.figure(figsize=(12, 8))

extended_flux = ext_norm_fit * ext_data
significance = extended_flux / sed_errors

plt.subplot(2, 1, 1)
plt.plot(
    angle_bin_centers,
    extended_flux,
    "ro-",
    linewidth=2,
    markersize=6,
    label="Extended Emission (fitted)",
)
plt.plot(
    angle_bin_centers,
    sed_errors,
    "ko--",
    linewidth=1,
    alpha=0.7,
    label="Data Errors (1σ)",
)
plt.plot(
    angle_bin_centers, 2 * sed_errors, "k:", linewidth=1, alpha=0.5, label="2σ errors"
)
plt.plot(
    angle_bin_centers, 3 * sed_errors, "k-.", linewidth=1, alpha=0.3, label="3σ errors"
)
plt.axhline(0, color="gray", linestyle="-", alpha=0.5)
plt.ylabel(r"$E^2 dN/dE$ [TeV cm$^{-2}$ s$^{-1}$]")
plt.title("Extended Emission vs Data Uncertainties")
plt.legend()
plt.yscale("log")
plt.grid(True, alpha=0.3)

plt.subplot(2, 1, 2)
plt.plot(angle_bin_centers, significance, "bo-", linewidth=2, markersize=6)
plt.axhline(1, color="red", linestyle="--", alpha=0.7, label="1σ threshold")
plt.axhline(2, color="orange", linestyle="--", alpha=0.7, label="2σ threshold")
plt.axhline(3, color="green", linestyle="--", alpha=0.7, label="3σ threshold")
plt.axhline(0, color="gray", linestyle="-", alpha=0.5)
plt.ylabel("Significance (σ)")
plt.xlabel(r"Distance squared [deg$^2$]")
plt.title("Extended Emission Significance")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Mean significance: {np.mean(significance):.2f}σ")
print(f"Max significance: {np.max(significance):.2f}σ")
print(f"Points > 2σ: {np.sum(significance > 2)}/{len(significance)}")
# Out:
# Mean significance: 1.45σ
# Max significance: 4.27σ
# Points > 2σ: 3/19

# %% [markdown]
# **Signal injection**

# %%
sed_values_inj = sed_values + ext_data*2.0

popt, pcov = curve_fit(
    fit_function,
    angle_bin_centers,
    sed_values_inj,
    sigma=sed_errors,
    p0=init_guess,
    absolute_sigma=True,
)

bkg_norm_fit, src_norm_fit, ext_norm_fit = popt
bkg_norm_err, src_norm_err, ext_norm_err = np.sqrt(np.diag(pcov))
fit = fit_function(angle_bin_centers, *popt)

print(rf"Background normalization: {bkg_norm_fit:.3f} $\pm$ {bkg_norm_err:.3f}")
print(rf"Source normalization: {src_norm_fit:.3f} $\pm$ {src_norm_err:.3f}")
print(rf"Ext. emission normalization: {ext_norm_fit:.3f} $\pm$ {ext_norm_err:.3f}")

chi2_value = np.sum(((sed_values_inj - fit) / sed_errors) ** 2)
ndof = len(sed_values) - 3
p_value = 1 - chi2.cdf(chi2_value, ndof)

print(f"chi2 = {chi2_value:.3f}")
print(f"chi2/ndof = {chi2_value / ndof:.3f} (ndof = {ndof})")
print(f"p-value = {p_value:.3f}")

def model_no_extended(angle_centers, bkg_norm, src_norm):
    return bkg_norm * corchkin_bkg + src_norm * corchkin_src


popt_no_ext, pcov_no_ext = curve_fit(
    model_no_extended,
    angle_bin_centers,
    sed_values_inj,
    sigma=sed_errors,
    p0=[1.0, 1.0],
    absolute_sigma=True,
)

fit_no_ext = model_no_extended(angle_bin_centers, *popt_no_ext)
chi2_no_ext = np.sum(((sed_values_inj - fit_no_ext) / sed_errors) ** 2)
ndof_no_ext = len(sed_values_inj) - 2

print(f"chi2/ndof without extended: {chi2_no_ext / ndof_no_ext:.3f}")
print(f"chi2/ndof with extended: {chi2_value / ndof:.3f}")

def f_test_nested(chi2_simple, ndof_simple, chi2_complex, ndof_complex):
    F = ((chi2_simple - chi2_complex) / (ndof_simple - ndof_complex)) / (
        chi2_complex / ndof_complex
    )
    p_value = 1 - chi2.cdf(F, ndof_simple - ndof_complex)
    return F, p_value


F_value, p_value_F = f_test_nested(chi2_no_ext, ndof_no_ext, chi2_value, ndof)

print(f"F-TEST")
print(f"F-value: {F_value:.3f}")
print(f"p-value: {p_value_F:.3f}")

if p_value_F < 0.05:
    print("Extended emission statistically significant (p < 0.05)")
elif p_value_F < 0.10:
    print("Extended emission marginally significant (p < 0.10)")
else:
    print("Extended emission not statistically significant")
# Out:
# Background normalization: 3.533 $\pm$ 0.334
# Source normalization: 2.570 $\pm$ 0.057
# Ext. emission normalization: 4.842 $\pm$ 1.143
# chi2 = 56.083
# chi2/ndof = 3.505 (ndof = 16)
# p-value = 0.000
# chi2/ndof without extended: 4.355
# chi2/ndof with extended: 3.505
# F-TEST
# F-value: 5.121
# p-value: 0.024
# Extended emission statistically significant (p < 0.05)

# %% [markdown]
# Questions: are the data from corochkin valid also for mrk421? Because i think they are for mrk501.
#
# What i did:
# 1) I fitted the data from CTAO with a model $c_1*source + c_2*background + c_3*(green line from Korochkin)$ to see if i get some extended signal -> I did not get any extended signal
# 2) I tried injecting it artificially and see if the data would be sensitive enough to detect it. So i did the same test with the data: CTAO + c_4*(green line). The signal seems now detectable with statistical relevance, but the problem is that i get a_3 too different from a_4 in the fit (for example if a_4=1, then a_3=4). For a_4 bigger, for example a_4=10, i get a_3 mutch more similar, but here i'm unsure hot to connect this result to a numerical value of the estimate of the sensitivity of CTAO to the magnetic field.
