# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates import SkyCoord
from numpy import cos,pi,sqrt,log10
from astropy.table import Table
from astropy.table import unique
import os
import ctadata
from astropy.io import ascii
from scipy import stats
from scipy.optimize import curve_fit

# %%
e_bins=np.logspace(np.log10(0.05), np.log10(50), 16)
e_mins=e_bins[:-1]
e_maxs=e_bins[1:]
e_means=sqrt(e_mins*e_maxs)
de=e_maxs-e_mins

th2_bins=np.linspace(0,0.16,17)
th2=(th2_bins[1:]+th2_bins[:-1])/2.

fit_params = np.empty(len(e_means), dtype=object)

# %%
fit_params = np.load("../crab_fit.npy", allow_pickle=True)

# %%
for i in range(len(e_means)):
    norm_tot, norm_t, sigma_c, sigma_t = fit_params[i]
    print(rf"$E \in [{e_mins[i]:.3f}, {e_maxs[i]:.3f}]$:")
    print(rf"Core Gaussian: $\sigma = {sigma_c:.3f}$")
    print(rf"Tail Gaussian 2: $\sigma = {sigma_t:.3f}, Norm = {norm_t:.3f}$")
    print("\n")
# Out:
# $E \in [0.050, 0.079]$:
# Core Gaussian: $\sigma = 0.102$
# Tail Gaussian 2: $\sigma = 0.159, Norm = 1.445$
#
#
# $E \in [0.079, 0.126]$:
# Core Gaussian: $\sigma = 0.095$
# Tail Gaussian 2: $\sigma = 0.213, Norm = 0.222$
#
#
# $E \in [0.126, 0.199]$:
# Core Gaussian: $\sigma = 0.071$
# Tail Gaussian 2: $\sigma = 0.154, Norm = 0.453$
#
#
# $E \in [0.199, 0.315]$:
# Core Gaussian: $\sigma = 0.074$
# Tail Gaussian 2: $\sigma = 0.161, Norm = 0.265$
#
#
# $E \in [0.315, 0.500]$:
# Core Gaussian: $\sigma = 0.065$
# Tail Gaussian 2: $\sigma = 0.155, Norm = 0.232$
#
#
# $E \in [0.500, 0.792]$:
# Core Gaussian: $\sigma = 0.061$
# Tail Gaussian 2: $\sigma = 0.151, Norm = 0.182$
#
#
# $E \in [0.792, 1.256]$:
# Core Gaussian: $\sigma = 0.056$
# Tail Gaussian 2: $\sigma = 0.139, Norm = 0.181$
#
#
# $E \in [1.256, 1.991]$:
# Core Gaussian: $\sigma = 0.056$
# Tail Gaussian 2: $\sigma = 0.156, Norm = 0.122$
#
#
# $E \in [1.991, 3.155]$:
# Core Gaussian: $\sigma = 0.052$
# ...
